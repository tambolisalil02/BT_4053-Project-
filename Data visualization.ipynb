# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import plotly.express as ex
import seaborn as sns
from IPython.display import display,HTML


pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
pd.set_option('display.width',None)

# %%
# Importing data to pd csv
data = pd.read_csv(r'E:\Data Science Projects\Fifa 21 data analysis\dataset\players_21.csv')
data.head(20)
# Out:
#     sofifa_id                                         player_url  \
# 0      158023  https://sofifa.com/player/158023/lionel-messi/...
# 1       20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2      200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3      188545  https://sofifa.com/player/188545/robert-lewand...
# 4      190871  https://sofifa.com/player/190871/neymar-da-sil...
# 5      192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 6      231747  https://sofifa.com/player/231747/kylian-mbappe...
# 7      192448  https://sofifa.com/player/192448/marc-andre-te...
# 8      203376  https://sofifa.com/player/203376/virgil-van-di...
# 9      212831  https://sofifa.com/player/212831/alisson-ramse...
# 10     208722  https://sofifa.com/player/208722/sadio-mane/21...
# 11     209331  https://sofifa.com/player/209331/mohamed-salah...
# 12     192119  https://sofifa.com/player/192119/thibaut-court...
# ...

# %% [markdown]
# ### Explore data

# %%
data.shape
# Out:
# (18944, 106)

# %%
data.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club_name',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=106)

# %%
skills=[]
for i in data.columns:
    skills.append(i)
skills
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'nationality',
#  'club_name',
#  'league_name',
#  'league_rank',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'player_positions',
#  'preferred_foot',
#  'international_reputation',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'team_position',
#  'team_jersey_number',
#  'loaned_from',
#  'joined',
#  'contract_valid_until',
#  'nation_position',
#  'nation_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
# ...

# %%
data.isnull().sum()
# Out:
# sofifa_id                         0
# player_url                        0
# short_name                        0
# long_name                         0
# age                               0
# dob                               0
# height_cm                         0
# weight_kg                         0
# nationality                       0
# club_name                       225
# league_name                     225
# league_rank                     225
# overall                           0
# potential                         0
# value_eur                         0
# wage_eur                          0
# player_positions                  0
# preferred_foot                    0
# international_reputation          0
# weak_foot                         0
# skill_moves                       0
# work_rate                         0
# body_type                         0
# real_face                         0
# release_clause_eur              995
# player_tags                   17536
# ...

# %%
fill_values = data.loc[:,['pace', 'shooting', 'passing', 'dribbling', 'defending','physic']]

for i in fill_values.columns:
    data[i].fillna(data[i].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# sofifa_id                         0
# player_url                        0
# short_name                        0
# long_name                         0
# age                               0
# dob                               0
# height_cm                         0
# weight_kg                         0
# nationality                       0
# club_name                       225
# league_name                     225
# league_rank                     225
# overall                           0
# potential                         0
# value_eur                         0
# wage_eur                          0
# player_positions                  0
# preferred_foot                    0
# international_reputation          0
# weak_foot                         0
# skill_moves                       0
# work_rate                         0
# body_type                         0
# real_face                         0
# release_clause_eur              995
# player_tags                   17536
# ...

# %% [markdown]
# ### Plotting based on Height

# %%
plt.figure(figsize = (22,8))
ax = sns.countplot(x ='height_cm', data = data)
ax.set_title(label = 'Count of players based on Height', fontsize=20)
ax.set_xlabel(xlabel = 'Heights in cm', fontsize=16)
ax.set_ylabel(ylabel = 'Count',fontsize=16)
plt.show()

# %% [markdown]
# ### Plot on Dribbling vs Height

# %%
plt.figure(figsize = (22,8))
plt.xlabel('Height', fontsize=20)
plt.ylabel('Dribbling', fontsize=20)
plt.title ('Dribbling vs Height', fontsize=25)

sns.barplot(x='shooting' , y='height_cm', data = data.sort_values('height_cm',inplace=False),alpha=1)
# Out:
# <Axes: title={'center': 'Dribbling vs Height'}, xlabel='shooting', ylabel='height_cm'>

# %% [markdown]
# ### Weight vs Height

# %%
plt.figure(figsize=(22,8))
plt.xlabel('Weight',fontsize = 20)
plt.ylabel('Height',fontsize=20)
plt.title('Weight vs Height Chart')
sns.barplot(x='height_cm', y='weight_kg', data = data.sort_values('height_cm'), alpha=1)
# Out:
# <Axes: title={'center': 'Weight vs Height Chart'}, xlabel='height_cm', ylabel='weight_kg'>

# %% [markdown]
# ### To Show Different Work rate of players

# %%
plt.figure(figsize=(15,7))
#plt.style.use('_classic_test')

sns.countplot(x='work_rate',data=data, palette='hls')
plt.title('Different work rates of the Players Participating in the FIFA 2021', fontsize = 20)
plt.xlabel('Work rates associated with the players', fontsize = 16)
plt.ylabel('count of Players', fontsize = 16)
plt.show()

# %% [markdown]
# ## Messi Vs Ronaldo

# %%
data.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club_name',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=106)

# %%
skills = ['pace',
 'shooting',
 'passing',
 'dribbling',
 'defending',
 'physic',
 'player_traits',
 'attacking_crossing',
 'attacking_finishing',
 'attacking_heading_accuracy',
 'attacking_short_passing',
 'attacking_volleys',
 'skill_dribbling',
 'skill_curve',
 'skill_fk_accuracy',
 'skill_long_passing',
 'skill_ball_control',
 'movement_acceleration',
 'movement_sprint_speed',
 'movement_agility',
 'movement_reactions',
 'movement_balance',
 'power_shot_power',
 'power_jumping',
 'power_stamina',
 'power_strength',
 'power_long_shots']

# %%
Messi = data.loc[data['short_name']=='L. Messi']
Messi = pd.DataFrame(Messi,columns=skills)

Ronaldo = data.loc[data['short_name']=='Cristiano Ronaldo']
Ronaldo = pd.DataFrame(Ronaldo,columns = skills)

plt.figure(figsize=(15,8))
sns.pointplot(data=Messi,color='blue')
sns.pointplot(data=Ronaldo, color='red')
plt.xticks(rotation=90)
plt.xlabel('Skills',fontsize=20)
plt.ylabel('Skill value',fontsize=20)
plt.title('Messi vs Roanldo', fontsize=25)
plt.grid()

# %% [markdown]
# ### Top 10 players based on Overall Skills

# %%
display(
HTML(data.sort_values('overall', ascending=False)[['short_name','overall']][:10].to_html(index=False)
    ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>short_name</th>
#       <th>overall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>L. Messi</td>
#       <td>93</td>
#     </tr>
#     <tr>
#       <td>Cristiano Ronaldo</td>
#       <td>92</td>
#     </tr>
#     <tr>
#       <td>J. Oblak</td>
#       <td>91</td>
#     </tr>
#     <tr>
#       <td>R. Lewandowski</td>
#       <td>91</td>
#     </tr>
#     <tr>
#       <td>Neymar Jr</td>
#       <td>91</td>
#     </tr>
#     <tr>
#       <td>K. De Bruyne</td>
#       <td>91</td>
#     </tr>
#     <tr>
#       <td>Alisson</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <td>S. Mané</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <td>M. Salah</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <td>V. van Dijk</td>
#       <td>90</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Top 5 nations with overall best players

# %%
top_nations = data.groupby(['nationality'])['overall'].max().sort_values(ascending=False).head(10)
top_nations
# Out:
# nationality
# Argentina      93
# Portugal       92
# Poland         91
# Brazil         91
# Slovenia       91
# Belgium        91
# Netherlands    90
# Egypt          90
# Senegal        90
# Germany        90
# Name: overall, dtype: int64

# %% [markdown]
# ### Top 5 clubs with overall Best Players

# %%
top_clubs = data.groupby(['club_name'])['overall'].max().sort_values(ascending=False).head(10)
top_clubs
# Out:
# club_name
# FC Barcelona           93
# Juventus               92
# Atlético Madrid        91
# Paris Saint-Germain    91
# Manchester City        91
# FC Bayern München      91
# Liverpool              90
# Real Madrid            89
# Chelsea                88
# Tottenham Hotspur      88
# Name: overall, dtype: int64

# %% [markdown]
# ### Age Distribution of Players in the clubs

# %%
top_club_names = ('FC Barcelona','Juventus','Real Madrid','Manchester City','Paris Saint-Germain')
clubs = data.loc[data['club_name'].isin(top_club_names) & data['age']]

fig,ax = plt.subplots()
fig.set_size_inches(10,10)
ax = sns.violinplot(x="club_name", y='age',data=clubs)
ax.set_title(label='Age distribution in the top 5 clubs', fontsize=25)
plt.xlabel('Clubs', fontsize=20)
plt.ylabel('Age', fontsize=20)
plt.grid()
